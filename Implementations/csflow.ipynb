# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/FYP
# Out:
# /content/drive/MyDrive/FYP

# %%
! git clone https://github.com/amazon-research/patchcore-inspection
# Out:
# Cloning into 'patchcore-inspection'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 57 (delta 8), reused 49 (delta 4), pack-reused 0
# Unpacking objects: 100% (57/57), done.

# %%
! git clone https://github.com/marco-rudolph/cs-flow
# Out:
# Cloning into 'cs-flow'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 104 (delta 16), reused 15 (delta 11), pack-reused 74
# Receiving objects: 100% (104/104), 27.57 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
cd /content/drive/MyDrive/FYP/cs-flow
# Out:
# /content/drive/MyDrive/FYP/cs-flow

# %%
pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=244eb6f2c3e23eb778661cf3406c6944fb3bd1ea4efeeb76eca1f5f0ba192793
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# ...

# %%
# !python main.py
# Out:
# Train epoch 0
# Epoch: 0.0 	 train loss: 1.5425
# Epoch: 0.4 	 train loss: 1.5416
# Epoch: 0.8 	 train loss: 1.5370
# Epoch: 0.12 	 train loss: 1.5258
# Epoch: 0.16 	 train loss: 1.5080
# Epoch: 0.20 	 train loss: 1.4845
# Epoch: 0.24 	 train loss: 1.4556
# Epoch: 0.28 	 train loss: 1.4220
# Epoch: 0.32 	 train loss: 1.3841
# Epoch: 0.36 	 train loss: 1.3425
# Epoch: 0.40 	 train loss: 1.2982
# Epoch: 0.44 	 train loss: 1.2517
# Epoch: 0.48 	 train loss: 1.2041
# Epoch: 0.52 	 train loss: 1.1562
# Epoch: 0.56 	 train loss: 1.1087
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: 1.3196
# AUROC: 	 last: 1.0000 	 max: 1.0000 	 epoch_max: 0 	 epoch_loss: 0
#
# Train epoch 1
#
# Compute loss and scores on test set:
# Epoch: 1 	 test_loss: 0.8947
# AUROC: 	 last: 1.0000 	 max: 1.0000 	 epoch_max: 0 	 epoch_loss: 0
#
# Train epoch 2
#
# Compute loss and scores on test set:
# Epoch: 2 	 test_loss: 0.7649
# AUROC: 	 last: 1.0000 	 max: 1.0000 	 epoch_max: 0 	 epoch_loss: 0
#
# ...

# %%
# !python evaluate.py
# Out:
# Compute maps, loss and scores on test set:
# AUC: 1.0

# %%
# !tar -xvf "/content/drive/MyDrive/FYP/cs-flow/data/images/toothbrush.tar.xz" -C "/content/drive/MyDrive/FYP/cs-flow/data/images/toothbrush"
# Out:
# toothbrush/
# toothbrush/ground_truth/
# toothbrush/ground_truth/defective/
# toothbrush/ground_truth/defective/011_mask.png
# toothbrush/ground_truth/defective/012_mask.png
# toothbrush/ground_truth/defective/013_mask.png
# toothbrush/ground_truth/defective/014_mask.png
# toothbrush/ground_truth/defective/015_mask.png
# toothbrush/ground_truth/defective/016_mask.png
# toothbrush/ground_truth/defective/017_mask.png
# toothbrush/ground_truth/defective/018_mask.png
# toothbrush/ground_truth/defective/019_mask.png
# toothbrush/ground_truth/defective/020_mask.png
# toothbrush/ground_truth/defective/021_mask.png
# toothbrush/ground_truth/defective/022_mask.png
# toothbrush/ground_truth/defective/023_mask.png
# toothbrush/ground_truth/defective/024_mask.png
# toothbrush/ground_truth/defective/025_mask.png
# toothbrush/ground_truth/defective/026_mask.png
# toothbrush/ground_truth/defective/027_mask.png
# toothbrush/ground_truth/defective/028_mask.png
# ...

# %%
# !python main.py
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b5-b6417697.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b5-b6417697.pth
# 100% 117M/117M [00:01<00:00, 83.4MB/s]
# Loaded pretrained weights for efficientnet-b5
#
# Train epoch 0
# Epoch: 0.0 	 train loss: 14.1893
# Epoch: 0.4 	 train loss: 13.3313
# Epoch: 0.8 	 train loss: 11.3024
# Epoch: 0.12 	 train loss: 8.6859
# Epoch: 0.16 	 train loss: 6.2247
# Epoch: 0.20 	 train loss: 4.2947
# Epoch: 0.24 	 train loss: 2.9285
# Epoch: 0.28 	 train loss: 2.2032
# Epoch: 0.32 	 train loss: 1.9742
# Epoch: 0.36 	 train loss: 1.8548
# Epoch: 0.40 	 train loss: 1.7755
# Epoch: 0.44 	 train loss: 1.7303
# Epoch: 0.48 	 train loss: 1.6930
# Epoch: 0.52 	 train loss: 1.6417
# Epoch: 0.56 	 train loss: 1.5957
#
# Compute loss and scores on test set:
# Epoch: 0 	 test_loss: 1.6073
# AUROC: 	 last: 0.8806 	 max: 0.8806 	 epoch_max: 0 	 epoch_loss: 0
#
# Train epoch 1
#
# ...

# %%
# !python evaluate.py
# Out:
# Loaded pretrained weights for efficientnet-b5
#
# Compute maps, loss and scores on test set:
# AUC: 0.9444444444444445
